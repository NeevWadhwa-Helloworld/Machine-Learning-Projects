# %% [markdown]
# <a href="https://colab.research.google.com/github/NeevWadhwa-Helloworld/Machine-Learning-Projects/blob/main/Pic_to_Pencil_Sketch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Pencil Sketch with Python**

# %%
pip install opencv-python

# %%
import cv2

# %%
image =cv2.imread("/content/sample_image.jpg")

cv2.waitKey(0)
# Out:
# -1

# %%
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
cv2.imwrite('gray_image_opencv.jpg', gray_image)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# /tmp/ipykernel_2133/3774970137.py in <cell line: 0>()
# ----> 1 gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
#       2 cv2.imwrite('gray_image_opencv.jpg', gray_image)
#
# error: OpenCV(4.13.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'

# %%
inverted_image=255-grey-image
cv2.imwrite('inverted', inverted_image)
cv2.waitKey()

# %%
blurred=cv2.GaussianBlur(inverted_image,(21,21),0)

# %%
inverted_blurred=255-blurred
pencil_sketch=cv2.divide(gray_image,inverted_blurred,scale=256.0)
cv2.imshow('sketch',pencil_sketch)
cv2.waitKey(0)
